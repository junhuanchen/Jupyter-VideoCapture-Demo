# %%
import platform
platform.uname()
# Out:
# ('Linux',
#  '7a449e2fcd2b',
#  '5.4.0-54-generic',
#  '#60-Ubuntu SMP Fri Nov 6 10:37:59 UTC 2020',
#  'aarch64',
#  '')

# %%
import time, os
print(time.time())
for i in os.popen('ps aux').readlines():
    print(i, ' ')
# Out:
# 1606820515.99
# ('USER         PID %CPU %MEM    VSZ   RSS TTY      STAT START   TIME COMMAND\n', ' ')
# ('root           1  0.0  0.0 223792  5652 pts/0    Ssl+ 10:59   0:00 /usr/bin/qemu-aarch64-static /bin/bash\n', ' ')
# ('root          17  0.0  0.0 224168  4140 ?        Ssl  10:59   0:00 /usr/bin/qemu-aarch64-static /usr/sbin/dropbear\n', ' ')
# ('root          93  0.0  0.0 224564  5080 ?        Ssl  11:00   0:00 /usr/bin/qemu-aarch64-static /usr/sbin/dropbear\n', ' ')
# ('root          95  0.1  0.0 223916  5300 pts/1    Ssl  11:00   0:00 /usr/bin/qemu-aarch64-static /bin/bash\n', ' ')
# ("root         101  2.5  0.2 1119620 45984 pts/1   Sl+  11:00   0:02 /usr/bin/qemu-aarch64-static /usr/bin/python -c import sys; sys.argv[0] = '/usr/bin/ipython'; from IPython.terminal.ipapp import launch_new_instance; launch_new_instance() kernel -f ./rik_kernel-175817cb-3acf-4acb-bdc8-be68e851bcc9.json\n", ' ')
# ...

# %%
print(os.popen('kill 107 109').readlines())

# %%
for i in os.popen('cat ./rik_kernel-320d1fcf-bf29-4c37-84eb-69c5021e72a8.json').readlines():
    print(i, ' ')

# %%
os.popen('netstat').readlines()

# %%
import os, time
import platform
print(platform.uname())
# print(os.popen('wget https://www.sipeed.com/banner-3.0d941a0c.jpg').readlines())
print(time.time(), os.getcwd(), os.listdir('/root'))
tmp = ["banner-4.1f289876.jpg", "banner-1.f1fd10d3.jpg"]

import IPython
from IPython.core.display import Image, display
notebook_display = IPython.display.display("", display_id=1)
while True:
    for i in tmp:
        notebook_display.update(IPython.display.Image(filename=i))
        time.sleep(0.01)
# Out:
# ('Linux', '7a449e2fcd2b', '5.4.0-54-generic', '#60-Ubuntu SMP Fri Nov 6 10:37:59 UTC 2020', 'aarch64', '')
# ...

# %%
print(time.time(), os.getcwd(), os.listdir('/root'))

# %%
import time
while True:
    print(time.time())
