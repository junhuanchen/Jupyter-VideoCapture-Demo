# %%
import platform
platform.uname()
# Out:
# ('Linux',
#  '7a449e2fcd2b',
#  '5.4.0-54-generic',
#  '#60-Ubuntu SMP Fri Nov 6 10:37:59 UTC 2020',
#  'aarch64',
#  '')

# %%
import time, os
print(time.time())
for i in os.popen('ps aux').readlines():
    print(i)
# Out:
# 1606816504.63
# USER         PID %CPU %MEM    VSZ   RSS TTY      STAT START   TIME COMMAND
#
# root           1  0.4  0.0 223792  5300 pts/0    Ssl+ 09:54   0:00 /usr/bin/qemu-aarch64-static /bin/bash
#
# root          17  0.0  0.0 224168  2964 ?        Ssl  09:54   0:00 /usr/bin/qemu-aarch64-static /usr/sbin/dropbear
#
# root          19  0.5  0.0 224564  4476 ?        Ssl  09:54   0:00 /usr/bin/qemu-aarch64-static /usr/sbin/dropbear
#
# root          21  0.7  0.0 223916  5300 pts/1    Ssl  09:54   0:00 /usr/bin/qemu-aarch64-static /bin/bash
#
# root          27 17.9  0.1 1119360 29268 pts/1   Sl+  09:54   0:02 /usr/bin/qemu-aarch64-static /usr/bin/python -c import sys; sys.argv[0] = '/usr/bin/ipython'; from IPython.terminal.ipapp import launch_new_instance; launch_new_instance() kernel -f ./rik_kernel-1907b01a-11eb-4b45-94ad-8d8f5b054b47.json
#
# root          33  0.7  0.0 224564  5360 ?        Ssl  09:54   0:00 /usr/bin/qemu-aarch64-static /usr/sbin/dropbear
#
# ...

# %%
print(os.popen('kill 21').readlines())
# Out:
# []

# %%
import os, time
import platform
print(platform.uname())
print(os.popen('wget https://www.sipeed.com/banner-1.f1fd10d3.jpg').readlines())
print(time.time(), os.getcwd(), os.listdir('/'))
from IPython.core.display import Image, display
display(Image(filename='./banner-1.f1fd10d3.jpg'))
# Out:
# ('Linux', '7a449e2fcd2b', '5.4.0-54-generic', '#60-Ubuntu SMP Fri Nov 6 10:37:59 UTC 2020', 'aarch64', '')
# []
# (1606816508.122682, '/root', ['sbin', 'bin', 'sys', 'root', 'proc', 'opt', 'dev', 'var', 'media', 'srv', 'etc', 'mnt', 'tmp', 'boot', 'lib', 'run', 'usr', 'home', 'maixpy.png', '.swp', '.dockerenv'])
